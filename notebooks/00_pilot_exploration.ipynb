# %% [markdown]
# # 00 — Pilot Exploration
#
# Scratch notebook for initial data inspection.  Placeholder — fill in as data arrives.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from src.scraping.market_data_loader import fetch_btc_ohlcv
from src.scraping.pboc_scraper import scrape_listings

# %%
# Quick Binance sanity check
btc = fetch_btc_ohlcv(interval='1h', limit=24)
btc.tail()

# %%
# TODO: scrape first PBOC listing page and inspect HTML structure
# articles = list(scrape_listings(max_pages=1))
# pd.DataFrame(articles)
